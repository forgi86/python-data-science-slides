# %% [markdown]
# # Data aggregation and group operations

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Basic aggregation and grouping

# %% [markdown]
# * Load the dataset auto.csv

# %%
df_auto = pd.read_csv("auto.csv")
df_auto.sample(5)
# Out:
#            make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 156      toyota       gas        std         four      sedan          fwd
# 107      peugot       gas        std         four      sedan          rwd
# 63        mazda    diesel        std          NaN      sedan          fwd
# 62        mazda       gas        std         four      sedan          fwd
# 182  volkswagen    diesel        std          two      sedan          fwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 156           front        95.7   166.3   64.4  ...           98         2bbl
# 107           front       107.9   186.7   68.4  ...          120         mpfi
# 63            front        98.8   177.8   66.5  ...          122          idi
# 62            front        98.8   177.8   66.5  ...          122         2bbl
# 182           front        97.3   171.7   65.5  ...           97          idi
#
#      bore stroke  compression-ratio horsepower  peak-rpm  city-mpg  \
# 156  3.19   3.03                9.0       70.0    4800.0        30
# 107  3.46   3.19                8.4       97.0    5000.0        19
# 63   3.39   3.39               22.7       64.0    4650.0        36
# 62   3.39   3.39                8.6       84.0    4800.0        26
# 182  3.01   3.40               23.0       52.0    4800.0        37
#
#      highway-mpg    price
# 156           37   6938.0
# 107           24  11900.0
# 63            42  10795.0
# 62            32  10245.0
# 182           46   7775.0
#
# [5 rows x 24 columns]

# %% [markdown]
# * Compute the mean of **horsepower**

# %%
df_auto["horsepower"].mean()
# Out:
# 104.25615763546799

# %% [markdown]
# * Compute the mean of **horsepower** for groups defined by **drive-wheels** (rwd, fwd, 4wd)

# %%
df_auto.groupby("drive-wheels")["horsepower"].mean()
# Out:
# drive-wheels
# 4wd     95.333333
# fwd     85.974576
# rwd    133.697368
# Name: horsepower, dtype: float64

# %% [markdown]
# * Compute the mean of **horsepower** and **price** for groups defined by **engine-location** (front, rear)

# %%
df_auto.groupby("engine-location")[["horsepower", "price"]].mean()
# Out:
#                  horsepower         price
# engine-location
# front               102.715  12884.085859
# rear                207.000  34528.000000

# %% [markdown]
# * Compute the median of all the numerica variables for groups defined by **fuel-type** and **aspiration**

# %%
df_auto.groupby(["fuel-type", "aspiration"]).median()
# Out:
#                       wheel-base  length  width  height  curb-weight  \
# fuel-type aspiration
# diesel    std               97.3   171.7   65.5    54.5       2275.0
#           turbo            107.9   187.5   68.4    56.5       3252.0
# gas       std               96.5   172.0   65.4    53.7       2385.0
#           turbo             96.6   173.2   66.3    51.8       2840.0
#
#                       engine-size   bore  stroke  compression-ratio  \
# fuel-type aspiration
# diesel    std               110.0  3.270    3.40               22.5
#           turbo             152.0  3.580    3.52               21.5
# gas       std               110.0  3.270    3.23                9.0
#           turbo             130.5  3.585    3.39                7.6
#
#                       horsepower  peak-rpm  city-mpg  highway-mpg    price
# fuel-type aspiration
# diesel    std               56.0    4650.0      37.0         46.0   7898.0
#           turbo             95.0    4350.0      26.0         27.0  17075.0
# gas       std               90.0    5200.0      25.0         31.0   9594.0
#           turbo            145.0    5350.0      19.0         24.0  14489.0

# %% [markdown]
# ## More advanced aggregations

# %% [markdown]
# * Compute mean and standard deviation of the columns **horsepower** and **peak-rpm**, for groups defined by **aspiration**

# %%
df_auto.groupby("aspiration")[["horsepower", "peak-rpm"]].agg([np.mean, np.std]) #.agg(["mean", "std"])
# Out:
#             horsepower                peak-rpm
#                   mean        std         mean         std
# aspiration
# std          99.759036  40.079191  5166.867470  464.743468
# turbo       124.432432  31.240590  4939.189189  505.680940

# %% [markdown]
# * Compute mean of **price** and the max of **horsepower** for groups defined by **make**

# %%
df_auto.groupby("make").agg({"price": np.mean, "horsepower": np.max}) #.agg({"price": "mean", "horsepower": "max"})
# Out:
#                       price  horsepower
# make
# alfa-romero    15498.333333       154.0
# audi           17859.166667       160.0
# bmw            26118.750000       182.0
# chevrolet       6007.000000        70.0
# dodge           7875.444444       145.0
# honda           8184.692308       101.0
# isuzu           8916.500000        90.0
# jaguar         34600.000000       262.0
# mazda          10652.882353       135.0
# mercedes-benz  33647.000000       184.0
# mercury        16503.000000       175.0
# mitsubishi      9239.769231       145.0
# nissan         10415.666667       200.0
# peugot         15489.090909       142.0
# plymouth        7963.428571       145.0
# porsche        31400.500000       288.0
# renault         9595.000000         NaN
# saab           15223.333333       160.0
# subaru          8541.250000       111.0
# toyota          9885.812500       161.0
# volkswagen     10077.500000       110.0
# volvo          18063.181818       162.0

# %% [markdown]
# ## General transformations

# %% [markdown]
# * Take the 3 most expensive cars (**price** column) per constructur (**make** column)

# %%
def top3_price(group_data):
    group_data_sort = group_data.sort_values(by="price", ascending=False)
    return group_data_sort.iloc[0:3]

# %%
df_auto.groupby("make", group_keys=False).apply(top3_price)
# Out:
#             make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 1    alfa-romero       gas        std          two  convertible          rwd
# 2    alfa-romero       gas        std          two    hatchback          rwd
# 0    alfa-romero       gas        std          two  convertible          rwd
# 8           audi       gas      turbo         four        sedan          fwd
# 7           audi       gas        std         four        wagon          fwd
# ..           ...       ...        ...          ...          ...          ...
# 191   volkswagen       gas        std         four        sedan          fwd
# 193   volkswagen       gas        std         four        wagon          fwd
# 204        volvo       gas      turbo         four        sedan          rwd
# 203        volvo    diesel      turbo         four        sedan          rwd
# 202        volvo       gas        std         four        sedan          rwd
#
#     engine-location  wheel-base  length  width  ...  engine-size  fuel-system  \
# 1             front        88.6   168.8   64.1  ...          130         mpfi
# 2             front        94.5   171.2   65.5  ...          152         mpfi
# 0             front        88.6   168.8   64.1  ...          130         mpfi
# 8             front       105.8   192.7   71.4  ...          131         mpfi
# 7             front       105.8   192.7   71.4  ...          136         mpfi
# ..              ...         ...     ...    ...  ...          ...          ...
# 191           front       100.4   180.2   66.9  ...          136         mpfi
# 193           front       100.4   183.1   66.9  ...          109         mpfi
# 204           front       109.1   188.8   68.9  ...          141         mpfi
# 203           front       109.1   188.8   68.9  ...          145          idi
# 202           front       109.1   188.8   68.9  ...          173         mpfi
#
#      bore stroke  compression-ratio horsepower  peak-rpm  city-mpg  \
# 1    3.47   2.68                9.0      111.0    5000.0        21
# 2    2.68   3.47                9.0      154.0    5000.0        19
# 0    3.47   2.68                9.0      111.0    5000.0        21
# 8    3.13   3.40                8.3      140.0    5500.0        17
# 7    3.19   3.40                8.5      110.0    5500.0        19
# ..    ...    ...                ...        ...       ...       ...
# 191  3.19   3.40                8.5      110.0    5500.0        19
# 193  3.19   3.40                9.0       88.0    5500.0        25
# 204  3.78   3.15                9.5      114.0    5400.0        19
# 203  3.01   3.40               23.0      106.0    4800.0        26
# 202  3.58   2.87                8.8      134.0    5500.0        18
#
#      highway-mpg    price
# 1             27  16500.0
# 2             26  16500.0
# 0             27  13495.0
# 8             20  23875.0
# 7             25  18920.0
# ..           ...      ...
# 191           24  13295.0
# 193           31  12290.0
# 204           25  22625.0
# 203           27  22470.0
# 202           23  21485.0
#
# [63 rows x 24 columns]

# %% [markdown]
# ## Pivoting

# %% [markdown]
# * Obtain the pivot table with the mean of **horsepower**, with **fuel-type** on the rows and **aspiration** on the columns

# %%
df_auto.pivot_table('horsepower', index="fuel-type", columns="aspiration", aggfunc="mean")
# Out:
# aspiration         std       turbo
# fuel-type
# diesel       58.142857   98.615385
# gas         101.591195  138.416667
